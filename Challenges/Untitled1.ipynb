# %%
from skimage import io
import matplotlib.pyplot as plt
url = 'https://www.sideshowtoy.com/wp-content/uploads/2018/03/dc-comics-batman-hush-superman-fabric-cape-edition-statue-prime1-studio-feature-903454-1.jpg'
image = io.imread(url)
plt.imshow(image)
plt.show()

# %%
import urllib2

BeforeImage = "https://www.sideshowtoy.com/wp-content/uploads/2018/03/dc-comics-batman-hush-superman-fabric-cape-edition-statue-prime1-studio-feature-903454-1.jpg" 

imageBefore = mpimg.imread(BeforeImage)
plt.imshow(imageBefore)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-e9f33a74ab2e> in <module>()
# ----> 1 import urllib2
#       2
#       3 BeforeImage = "https://www.sideshowtoy.com/wp-content/uploads/2018/03/dc-comics-batman-hush-superman-fabric-cape-edition-statue-prime1-studio-feature-903454-1.jpg"
#       4
#       5 imageBefore = mpimg.imread(BeforeImage)
#
# ModuleNotFoundError: No module named 'urllib2'
