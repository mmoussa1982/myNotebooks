# %% [markdown]
# # Installing Custom Vision Python Library

# %% [markdown]
# Run this in the Anaconda cmd to Install the Custom Vision APIs
#
# pip install azure-cognitiveservices-vision-customvision

# %%
# pip install azure-cognitiveservices-vision-customvision

# %%
from azure.cognitiveservices.vision.customvision.training import training_api
from azure.cognitiveservices.vision.customvision.training.models import ImageUrlCreateEntry

# %%
training_key = 'e2e548f745f34742af0ea36b83b5cf28'
prediction_key = 'c983aeed1323427195e606dab0646a5f'

project_name = 'cvision Challange'

# %% [markdown]
# ### Create Project

# %%
trainer = training_api.TrainingApi(training_key)

# Create a new project
print ('Creating project...')
project = trainer.create_project(project_name)
# Out:
# Creating project...

# %% [markdown]
# ### Add Tags & Images

# %%
import os
os.chdir('D:/MyWorx/Courses/PAF Bootcamp/Challenges/Images/gear_images')

all_subdirs = [d for d in os.listdir('.') if os.path.isdir(d)]
for dirs in all_subdirs:
    tag = trainer.create_tag(project.id,dirs)
    print(tag.id + ' ' + tag.name)
    for image in os.listdir(os.fsencode('./'+dirs)):
       print(image) 
       with open('./'+dirs + "/" + os.fsdecode(image), mode="rb") as img_data: 
           trainer.create_images_from_data(project.id, img_data, [ tag.id ])
# Out:
# e6215812-a24a-4714-a7ef-0f1e32d7bb74 axes
# b'100172.jpeg'
# b'10036053x1012980_zm.jpeg'
# b'10045714_zm.jpeg'
# b'100937.jpeg'
# b'100938.jpeg'
# b'10101173x1012980_zm.jpeg'
# b'10188438x1011898_zm.jpeg'
# b'10189964_zm.jpeg'
# b'10189970_zm.jpeg'
# b'10189971_zm.jpeg'
# b'10215531x1028317_zm.jpeg'
# b'10258915x1152209_zm.jpeg'
# b'10260981_zm.jpeg'
# b'10260983_zm.jpeg'
# b'10285571x1013345_zm.jpeg'
# b'10285573x1013345_zm.jpeg'
# b'10291030_zm.jpeg'
# b'10291102_zm.jpeg'
# b'10321075_zm.jpeg'
# b'10331860x1078795_zm.jpeg'
# b'10331871x1010938_zm.jpeg'
# b'10347141x1152209_zm.jpeg'
# b'10351594_zm.jpeg'
# b'10351595_zm.jpeg'
# b'10351608_zm.jpeg'
# b'10353611_zm.jpeg'
# b'10353612_zm.jpeg'
# b'10353624_zm.jpeg'
# b'10353625_zm.jpeg'
# b'107254.jpeg'
# b'113409.jpeg'
# b'113410.jpeg'
# b'1312778_000_main.jpg'
# b'1312779_000_main.jpg'
# b'1312786_004_main.jpg'
# b'1312788_004_main.jpg'
# b'1312790_004_main.jpg'
# b'1312793_915_main.jpg'
# b'1312794_000_main.jpg'
# ...
